# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tky823/machine-learning_study-group/blob/main/DeepLearningFromScratch/ch04/sec04/numerical_gradient.ipynb)

# %%
import numpy as np

# %% [markdown]
# \begin{align*}
#     f_{2}(x_{0}, x_{1})
#     & := x_{0}^{2} + x_{1}^{2} \\
#     \nabla f_{2}(x_{0}, x_{1})
#     & = (2x_{0}, 2x_{1})
# \end{align*}

# %%
def function_2(x):
    return np.sum(x**2)

# %%
def bad_numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x) # xと同じ形状の配列を生成

    for idx in range(x.size):
        tmp_val = x[idx]
        # f(x+h)の計算
        x[idx] = tmp_val + h
        fxh1 = f(x)

        # f(x-h)の計算
        x[idx] = tmp_val - h
        fxh2 = f(x)
        grad[idx] = (fxh1 - fxh2) / (2*h)
        # x[idx] = tmp_val
    
    return grad

# %% [markdown]
# $(x_{0}, x_{1}) = (3, 4)$の場合，
# \begin{align*}
#     \left.\nabla f_{2}(x_{0}, x_{1})\right|_{(x_{0}, x_{1})} = (6, 8)
# \end{align*}

# %%
x = np.array([3.0, 4.0])

# %%
numerical_gradient(function_2, x)
